# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np

# %%
with open('../data/fig_2/formation_fast.pkl', 'rb') as f:
    fast = pickle.load(f)
with open('../data/fig_2/formation_slow.pkl', 'rb') as f:
    slow = pickle.load(f)

# %%
fig, ax = plt.subplots(nrows=2)
ax[0].plot(slow[0]['f'][0], alpha=0.5)
ax[0].axvline(np.where(slow[0]['PP_onset'][0] == True)[0])
ax[1].plot(slow[1]['f'][0], alpha=0.5)
ax[1].axvline(np.where(slow[0]['PP_onset'][0] == True)[0])

# %%
fig, ax = plt.subplots(nrows=2)
ax[0].plot(fast[0]['f'][0], alpha=0.5)
ax[0].axvline(np.where(fast[0]['PP_onset'][0] == True)[0])
ax[1].plot(fast[1]['f'][0], alpha=0.5)
ax[1].axvline(np.where(fast[0]['PP_onset'][0] == True)[0])

# %%
plt.plot(fast[1]['V_prox'][0])

# %%
plt.plot(slow[1]['V_prox'][0])

# %%
slow[0]['PP_onset'][0].sum()
# Out:
# np.float64(1.0)

# %%
fast[0]['PP_onset'][0].sum()
# Out:
# np.float64(1.0)

# %%
np.where(slow[0]['PP_onset'][0] == True)
# Out:
# (array([199]),)

# %%
np.where(fast[0]['PP_onset'][0] == True)
# Out:
# (array([199]),)

# %%
    with open('../data/fig_2/consolitdation.pkl', 'rb') as f:
        consolidation = pickle.load(f)

    with open('../data/fig_2/remapping.pkl', 'rb') as f:
        remapping = pickle.load(f)    
    extension = ''
